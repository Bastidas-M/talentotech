# %% [markdown]
# ##**Script de fuerza bruta a texto con cifrado César**

# %%
import pandas as pd
import string
import matplotlib.pyplot as plt

alfabeto = "abcdefghijklmnñopqrstuvwxyz"

#Cifrado César (para cifrar y descifra con desplazamiento)
def cifrado_cesar_es(texto, desplazamiento):
    resultado = ""
    for caracter in texto:
        if caracter.lower() in alfabeto:
            es_mayus = caracter.isupper()
            indice = alfabeto.index(caracter.lower())
            nuevo_indice = (indice + desplazamiento) % len(alfabeto)
            nuevo_caracter = alfabeto[nuevo_indice]
            resultado += nuevo_caracter.upper() if es_mayus else nuevo_caracter
        else:
            resultado += caracter
    return resultado

#Descifrar llamando cifrado con desplazamiento
def descifrado_cesar_es(texto_cifrado, desplazamiento):
    return cifrado_cesar_es(texto_cifrado, -desplazamiento)

#Descifrar con todas las claves posibles en español
def decifrado_total_es(texto_cifrado):
    resultados = []
    for i in range(len(alfabeto)):
        resultados.append(descifrado_cesar_es(texto_cifrado, i))
    return resultados

# DataFrame inicial
datos = {
    'msj_original': [
        "Hola mundo",
        "Estoy en clase",
        "Mañana es primero de mayo",
        "¿cómo estás?",
        "Este es un mensaje de prueba",
        "Colombia",
        "Ciberseguridad",
        "¡Hola!",
        "Conociendo el cifrado cesar .23$5&",
        "Realizar actididades"
    ],
    'clave': [29, 31, 1, 3, 5, 7, 10, 15, 24, 11]
}

# DataFrame
df = pd.DataFrame(datos)

# Aplicar cifrado César
def aplicar_cifrado_cesar_es(row):
    return cifrado_cesar_es(row['msj_original'], row['clave'])

df['msj_cifrado'] = df.apply(aplicar_cifrado_cesar_es, axis=1)

# Descifrar con todas las claves en español
def aplicar_descifrado_total_es(row):
    return decifrado_total_es(row['msj_cifrado'])

df['msj_descifrado'] = df.apply(aplicar_descifrado_total_es, axis=1)

# DataFrame
df
# Out:
#                          msj_original  clave  \
# 0                          Hola mundo     29
# 1                      Estoy en clase     31
# 2           Mañana es primero de mayo      1
# 3                        ¿cómo estás?      3
# 4        Este es un mensaje de prueba      5
# 5                            Colombia      7
# 6                      Ciberseguridad     10
# 7                              ¡Hola!     15
# 8  Conociendo el cifrado cesar .23$5&     24
# 9                Realizar actididades     11
#
#                           msj_cifrado  \
# 0                          Jqnc ñwofq
# 1                      Iwxsc iq goewi
# 2           Nbobñb ft qsjnfsp ef nbzp
# 3                        ¿fóor hvwáv?
# 4        Jxyj jx zr qjrxfñj ij uwzjgf
# 5                            Jvrvsioh
# 6                      Mrlñbcñpebrnkn
# 7                              ¡Vdzo!
# 8  Zmkmzfbkam bi zfcoxam zbpxo .23$5&
# 9                Colvsklc lnesñsñlñod
#
#                                       msj_descifrado
# 0  [Jqnc ñwofq, Ipmb nvñep, Hola mundo, Gñkz ltmc...
# 1  [Iwxsc iq goewi, Hvwrb hp fñdvh, Guvqa go encu...
# 2  [Nbobñb ft qsjnfsp ef nbzp, Mañana es primero ...
# 3  [¿fóor hvwáv?, ¿eóñq guváu?, ¿dónp ftuát?, ¿có...
# 4  [Jxyj jx zr qjrxfñj ij uwzjgf, Iwxi iw yq piqw...
# 5  [Jvrvsioh, Iuqurhñg, Htptqgnf, Gsospfme, Frñro...
# 6  [Mrlñbcñpebrnkn, Lqknabnodaqmjm, Kpjmzamñczpli...
# 7  [¡Vdzo!, ¡Ucyñ!, ¡Tbxn!, ¡Sawm!, ¡Rzvl!, ¡Qyuk...
# 8  [Zmkmzfbkam bi zfcoxam zbpxo .23$5&, Yljlyeajz...
# 9  [Colvsklc lnesñsñlñod, Bñkurjkb kmdrnrnknñc, A...

# %% [markdown]
# ##**Cifrado Vigenere**

# %%
import pandas as pd

alfabeto = "abcdefghijklmnñopqrstuvwxyz"

#Obtener los desplazamientos de las letras de la clave
def obtener_desplazamientos(clave):
    return [alfabeto.index(letra) for letra in clave]

#Cifrado Vigenere
def cifrado_vigenere_es(texto, clave):
    texto = texto.lower()
    clave = clave.lower()
    desplazamientos = obtener_desplazamientos(clave)
    resultado = ""
    clave_len = len(desplazamientos)
    i = 0

    for caracter in texto:
        if caracter in alfabeto:
            indice = alfabeto.index(caracter)
            nuevo_indice = (indice + desplazamientos[i % clave_len]) % len(alfabeto)
            resultado += alfabeto[nuevo_indice]
            i += 1
        else:
            resultado += caracter
    return resultado

#Descifrado Vigenere
def descifrado_vigenere_es(texto_cifrado, clave):
    texto_cifrado = texto_cifrado.lower()
    clave = clave.lower()
    desplazamientos = obtener_desplazamientos(clave)
    resultado = ""
    clave_len = len(desplazamientos)
    i = 0

    for caracter in texto_cifrado:
        if caracter in alfabeto:
            indice = alfabeto.index(caracter)
            nuevo_indice = (indice - desplazamientos[i % clave_len]) % len(alfabeto)
            resultado += alfabeto[nuevo_indice]
            i += 1
        else:
            resultado += caracter
    return resultado

datos = {
    'msj_original': ['platzi'],
    'clave': ['ckf']
}

df = pd.DataFrame(datos)

#Aplicar cifrado
df['msj_cifrado'] = df.apply(lambda row: cifrado_vigenere_es(row['msj_original'], row['clave']), axis=1)

#Aplicar descifrado
df['msj_descifrado'] = df.apply(lambda row: descifrado_vigenere_es(row['msj_cifrado'], row['clave']), axis=1)

df
# Out:
#   msj_original clave msj_cifrado msj_descifrado
# 0       platzi   ckf      rufvjn         platzi

# %% [markdown]
# #**Cifrado Vigenere con análisis frecuencia y detecció por diccionario**

# %%
from collections import Counter
import numpy as np
import itertools

alfabeto = "abcdefghijklmnñopqrstuvwxyz"

# Función para cargar el diccionario
def cargar_diccionario_es():
    ruta = "diccionario.txt"
    with open(ruta, 'r', encoding='utf-8') as f:
        diccionario = set(line.strip().lower() for line in f if line.strip())
    return diccionario

diccionario = cargar_diccionario_es()

# Función de conversion de clave a lista de desplazamientos
def obtener_desplazamientos(clave):
    return [alfabeto.index(letra) for letra in clave]

# Función de descifrado Vigenere
def descifrado_vigenere_es(texto_cifrado, clave):
    texto_cifrado = texto_cifrado.lower()
    clave = clave.lower()
    desplazamientos = obtener_desplazamientos(clave)
    resultado = ""
    clave_len = len(desplazamientos)
    i = 0

    for caracter in texto_cifrado:
        if caracter in alfabeto:
            indice = alfabeto.index(caracter)
            nuevo_indice = (indice - desplazamientos[i % clave_len]) % len(alfabeto)
            resultado += alfabeto[nuevo_indice]
            i += 1
        else:
            resultado += caracter
    return resultado

# Función de cifrado Vigenere
def cifrado_vigenere_es(texto, clave):
    texto = texto.lower()
    clave = clave.lower()
    desplazamientos = obtener_desplazamientos(clave)
    resultado = ""
    clave_len = len(desplazamientos)
    i = 0

    for caracter in texto:
        if caracter in alfabeto:
            indice = alfabeto.index(caracter)
            nuevo_indice = (indice + desplazamientos[i % clave_len]) % len(alfabeto)
            resultado += alfabeto[nuevo_indice]
            i += 1
        else:
            resultado += caracter
    return resultado

# Función para validar el texto descifrado
def validar_texto_completo(texto_descifrado, diccionario, longitud_minima=4, porcentaje_minimo=50):
    palabras = texto_descifrado.split()
    if not palabras:
        return False, 0, {}

    palabras_largas = [p for p in palabras if len(p) >= longitud_minima]
    palabras_validas = [p for p in palabras_largas if p in diccionario]

    todas_palabras_validas = [p for p in palabras if p in diccionario]

    # Calcular métricas
    total_palabras = len(palabras)
    palabras_largas_count = len(palabras_largas)
    palabras_validas_count = len(palabras_validas)
    todas_validas_count = len(todas_palabras_validas)

    # Porcentajes
    porcentaje_palabras_largas = (palabras_largas_count / total_palabras * 100) if total_palabras > 0 else 0
    porcentaje_validas_de_largas = (palabras_validas_count / palabras_largas_count * 100) if palabras_largas_count > 0 else 0
    porcentaje_total_validas = (todas_validas_count / total_palabras * 100) if total_palabras > 0 else 0


    detalles = {
        'total_palabras': total_palabras,
        'palabras_largas': palabras_largas_count,
        'palabras_validas_largas': palabras_validas_count,
        'todas_palabras_validas': todas_validas_count,
        'palabras_validas_largas_lista': palabras_validas,
        'todas_palabras_validas_lista': todas_palabras_validas,
        'porcentaje_total_validas': porcentaje_total_validas,
        'porcentaje_validas_largas': porcentaje_validas_de_largas
    }


    es_muy_probable = (
        (palabras_validas_count >= 2 and porcentaje_validas_de_largas >= 70) or
        (porcentaje_total_validas >= porcentaje_minimo and todas_validas_count >= 3)
    )

    return es_muy_probable, detalles

# Función para generar las claves posibles
def generar_todas_las_claves(longitud_maxima):

    for longitud in range(1, longitud_maxima + 1):
        for combinacion in itertools.product(alfabeto, repeat=longitud):
            yield ''.join(combinacion)

# ATAQUE DE FUERZA BRUTA COMPLETA
def ataque_fuerza_bruta_completa(texto_cifrado, diccionario, longitud_maxima_clave=5,
                                mostrar_progreso=True, limite_candidatos=10):
    print("ATAQUE DE FUERZA BRUTA")
    print(f"Longitud máxima de clave: {longitud_maxima_clave}")

    # Calcular total de combinaciones
    total_combinaciones = sum(len(alfabeto) ** i for i in range(1, longitud_maxima_clave + 1))
    print(f"otal de combinaciones a probar: {total_combinaciones:,}")
    for i in range(1, longitud_maxima_clave + 1):
        combinaciones_longitud = len(alfabeto) ** i
        print(f"   - Longitud {i}: {combinaciones_longitud:,} combinaciones")

    print("=" * 80)

    candidatos = []
    intentos = 0
    mejores_candidatos = []


    for clave in generar_todas_las_claves(longitud_maxima_clave):
        intentos += 1

        # Descifrar con la clave actual
        texto_descifrado = descifrado_vigenere_es(texto_cifrado, clave)

        # Validar el resultado
        es_muy_probable, detalles = validar_texto_completo(texto_descifrado, diccionario)

        # Si encontramos un candidato muy probable, lo guardamos
        if es_muy_probable:
            candidato = {
                'clave': clave,
                'texto': texto_descifrado,
                'detalles': detalles,
                'intento': intentos
            }
            candidatos.append(candidato)

            print(f"Clave: '{clave}' (intento #{intentos:,})")
            print(f"Palabras válidas largas: {', '.join(detalles['palabras_validas_largas_lista'])}")
            print(f"Todas las palabras válidas: {', '.join(detalles['todas_palabras_validas_lista'])}")
            print(f"Estadísticas detalladas:")
            print(f"   - Total palabras: {detalles['total_palabras']}")
            print(f"   - Palabras válidas (todas): {detalles['todas_palabras_validas']} ({detalles['porcentaje_total_validas']:.1f}%)")
            print(f"   - Palabras válidas largas: {detalles['palabras_validas_largas']} ({detalles['porcentaje_validas_largas']:.1f}%)")
            print(f"Texto descifrado: '{texto_descifrado}'")
            print("-" * 60)

    print(f"Total de intentos realizados: {intentos:,}")
    print(f"Candidatos muy probables encontrados: {len(candidatos)}")

    if candidatos:

        for i, candidato in enumerate(candidatos[:limite_candidatos], 1):
            print(f"\n#{i} - CLAVE: '{candidato['clave']}'")
            print(f"Palabras válidas: {', '.join(candidato['detalles']['todas_palabras_validas_lista'])}")
            print(f"Texto descifrado: '{candidato['texto']}'")
            print(f"Encontrada en intento: #{candidato['intento']:,}")

        mejor_candidato = candidatos[0]
        return mejor_candidato['clave'], mejor_candidato['texto']

    else:
        print("\nNo se encontraron candidatos muy probables.")
        if mejores_candidatos:
            print(f"\nMEJORES CANDIDATOS ALTERNATIVOS:")
            for i, candidato in enumerate(mejores_candidatos[:5], 1):
                print(f"\n#{i} - CLAVE: '{candidato['clave']}'")
                print(f"Texto: '{candidato['texto']}'")

        return None, None

if __name__ == "__main__":
    texto_original = "el conocimiento es poder"
    clave_real = "abc"

    print("TEXTO ORIGINAL:", texto_original)
    print("CLAVE REAL:", clave_real)

    # Cifrar el texto
    texto_cifrado = cifrado_vigenere_es(texto_original, clave_real)
    print("TEXTO CIFRADO:", texto_cifrado)
    print("=" * 80)

    # Ejecutar ataque de fuerza bruta
    clave_encontrada, texto_descifrado = ataque_fuerza_bruta_completa(
        texto_cifrado,
        diccionario,
        longitud_maxima_clave=5,
        limite_candidatos=5
    )

    if clave_encontrada:
        print(f"\nATAQUE EXITOSO!")
        print(f"Clave encontrada: '{clave_encontrada}'")
        print(f"Clave real: '{clave_real}'")
        print(f"Coincide: {'Sí' if clave_encontrada == clave_real else 'No'}")
        print(f"Texto recuperado: '{texto_descifrado}'")
    else:
        print(f"\nATAQUE FALLIDO - No se encontró la clave correcta")
        print("Sugerencias:")
        print("   - La clave podría ser más larga que 5 caracteres")
        print("   - El diccionario podría no contener las palabras del texto")
        print("   - Los criterios de validación podrían ser muy estrictos")
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca vujoqatdddlv bq fijar'
# ------------------------------------------------------------
# Clave: 'cmmkx' (intento #1,860,001)
# Palabras válidas largas: fftir
# Todas las palabras válidas: ca, jq, fftir
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca sfqoqxelddig jq fftir'
# ------------------------------------------------------------
# Clave: 'cmnab' (intento #1,860,437)
# Palabras válidas largas: feder
# Todas las palabras válidas: ca, fq, feder
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca ronoqwñhddhp fq feder'
# ------------------------------------------------------------
# Clave: 'cmnaq' (intento #1,860,453)
# Palabras válidas largas: fedor
# Todas las palabras válidas: ca, pq, fedor
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca roxoqwñrddhp pq fedor'
# ------------------------------------------------------------
# Clave: 'cmnib' (intento #1,860,653)
# Palabras válidas largas: fever
# Todas las palabras válidas: ca, fq, fever
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca rhnoqwghddhi fq fever'
# ------------------------------------------------------------
# Clave: 'cmnkq' (intento #1,860,723)
# Palabras válidas largas: fetor
# Todas las palabras válidas: ca, pq, fetor
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca rfxoqwerddhg pq fetor'
# ------------------------------------------------------------
# Clave: 'cmnmx' (intento #1,860,784)
# Palabras válidas largas: ferir
# Todas las palabras válidas: ca, jq, ferir
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca rdqoqwclddhe jq ferir'
# ------------------------------------------------------------
# Clave: 'cmnrf' (intento #1,860,927)
# Palabras válidas largas: femar
# Todas las palabras válidas: ca, bq, femar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca rxjoqwwdddhy bq femar'
# ------------------------------------------------------------
# Clave: 'cmnrl' (intento #1,860,933)
# Palabras válidas largas: femur
# Todas las palabras válidas: ca, vq, femur
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca rxdoqwwxddhy vq femur'
# ------------------------------------------------------------
# Clave: 'cmpeu' (intento #1,862,752)
# Palabras válidas largas: fbzlr
# Todas las palabras válidas: ca, mq, fbzlr
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca oltoqtkñddem mq fbzlr'
# ------------------------------------------------------------
# Clave: 'cmqaf' (intento #1,863,357)
# Palabras válidas largas: fadar
# Todas las palabras válidas: ca, bq, fadar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca ñojoqsñddddp bq fadar'
# ------------------------------------------------------------
# Clave: 'cmqbb' (intento #1,863,380)
# Palabras válidas largas: facer
# Todas las palabras válidas: ca, fq, facer
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca ññnoqsnhdddo fq facer'
# ------------------------------------------------------------
# Clave: 'cmqcb' (intento #1,863,407)
# Palabras válidas largas: faber
# Todas las palabras válidas: ca, fq, faber
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca ñnnoqsmhdddñ fq faber'
# ------------------------------------------------------------
# Clave: 'cmqiq' (intento #1,863,585)
# Palabras válidas largas: favor
# Todas las palabras válidas: ca, pq, favor
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca ñhxoqsgrdddi pq favor'
# ------------------------------------------------------------
# Clave: 'cmqkq' (intento #1,863,639)
# Palabras válidas largas: fator
# Todas las palabras válidas: ca, pq, fator
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca ñfxoqserdddg pq fator'
# ------------------------------------------------------------
# Clave: 'cmqpf' (intento #1,863,789)
# Palabras válidas largas: fañar
# Todas las palabras válidas: ca, bq, fañar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca ñzjoqsydddda bq fañar'
# ------------------------------------------------------------
# Clave: 'cmqsx' (intento #1,863,889)
# Palabras válidas largas: falir
# Todas las palabras válidas: ca, jq, falir
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca ñwqoqsvldddx jq falir'
# ------------------------------------------------------------
# Clave: 'cmquf' (intento #1,863,924)
# Palabras válidas largas: fajar
# Todas las palabras válidas: ca, bq, fajar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca ñujoqstddddv bq fajar'
# ------------------------------------------------------------
# Clave: 'cmwbf' (intento #1,867,758)
# Palabras válidas largas: fucar
# Todas las palabras válidas: ca, bq, fucar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca iñjoqnndddxo bq fucar'
# ------------------------------------------------------------
# Clave: 'cmwcf' (intento #1,867,785)
# Palabras válidas largas: fubar
# Todas las palabras válidas: ca, bq, fubar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca injoqnmdddxñ bq fubar'
# ------------------------------------------------------------
# Clave: 'cmwlq' (intento #1,868,040)
# Palabras válidas largas: fusor
# Todas las palabras válidas: ca, pq, fusor
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca iexoqndrddxf pq fusor'
# ------------------------------------------------------------
# Clave: 'cmwmq' (intento #1,868,067)
# Palabras válidas largas: furor
# Todas las palabras válidas: ca, pq, furor
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca idxoqncrddxe pq furor'
# ------------------------------------------------------------
# Clave: 'cmwpf' (intento #1,868,163)
# Palabras válidas largas: fuñar
# Todas las palabras válidas: ca, bq, fuñar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca izjoqnydddxa bq fuñar'
# ------------------------------------------------------------
# Clave: 'cmwrf' (intento #1,868,217)
# Palabras válidas largas: fumar
# Todas las palabras válidas: ca, bq, fumar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca ixjoqnwdddxy bq fumar'
# ------------------------------------------------------------
# Clave: 'cmwsf' (intento #1,868,244)
# Palabras válidas largas: fular
# Todas las palabras válidas: ca, bq, fular
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca iwjoqnvdddxx bq fular'
# ------------------------------------------------------------
# Clave: 'cmwxf' (intento #1,868,379)
# Palabras válidas largas: fugar
# Todas las palabras válidas: ca, bq, fugar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca irjoqnqdddxs bq fugar'
# ------------------------------------------------------------
# Clave: 'cmwxx' (intento #1,868,398)
# Palabras válidas largas: fugir
# Todas las palabras válidas: ca, jq, fugir
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca irqoqnqlddxs jq fugir'
# ------------------------------------------------------------
# Clave: 'cmwyf' (intento #1,868,406)
# Palabras válidas largas: fufar
# Todas las palabras válidas: ca, bq, fufar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca iqjoqnpdddxr bq fufar'
# ------------------------------------------------------------
# Clave: 'cmzdb' (intento #1,869,995)
# Palabras válidas largas: fraer
# Todas las palabras válidas: ca, fq, fraer
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca fmnoqklhddun fq fraer'
# ------------------------------------------------------------
# Clave: 'cmzjx' (intento #1,870,180)
# Palabras válidas largas: fruir
# Todas las palabras válidas: ca, jq, fruir
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca fgqoqkfldduh jq fruir'
# ------------------------------------------------------------
# Clave: 'cmzvq' (intento #1,870,524)
# Palabras válidas largas: frior
# Todas las palabras válidas: ca, pq, frior
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca ftxoqksrdduu pq frior'
# ------------------------------------------------------------
# Clave: 'cmzzh' (intento #1,870,622)
# Palabras válidas largas: freyr
# Todas las palabras válidas: ca, zq, freyr
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca fphoqkobdduq zq freyr'
# ------------------------------------------------------------
# Clave: 'cmzzx' (intento #1,870,639)
# Palabras válidas largas: freir
# Todas las palabras válidas: ca, jq, freir
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ca fpqoqkoldduq jq freir'
# ------------------------------------------------------------
# Clave: 'cncrb' (intento #1,872,587)
# Palabras válidas largas: eomer
# Todas las palabras válidas: cz, fq, eomer
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cz cxnophwhdcry fq eomer'
# ------------------------------------------------------------
# Clave: 'cneab' (intento #1,873,559)
# Palabras válidas largas: ender
# Todas las palabras válidas: cz, fq, ender
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cz aonopfñhdcpp fq ender'
# ------------------------------------------------------------
# Clave: 'cneaq' (intento #1,873,575)
# Palabras válidas largas: endor
# Todas las palabras válidas: cz, pq, endor
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cz aoxopfñrdcpp pq endor'
# ------------------------------------------------------------
# Clave: 'cnekb' (intento #1,873,829)
# Palabras válidas largas: enter
# Todas las palabras válidas: cz, fq, enter
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cz afnopfehdcpg fq enter'
# ------------------------------------------------------------
# Clave: 'cnfcb' (intento #1,874,342)
# Palabras válidas largas: ember
# Todas las palabras válidas: cz, fq, ember
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cz znnopemhdcoñ fq ember'
# ------------------------------------------------------------
# Clave: 'cngab' (intento #1,875,017)
# Palabras válidas largas: elder
# Todas las palabras válidas: cz, fq, elder
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cz yonopdñhdcñp fq elder'
# ------------------------------------------------------------
# Clave: 'cngef' (intento #1,875,129)
# Palabras válidas largas: elzar
# Todas las palabras válidas: cz, bq, elzar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cz yljopdkddcñm bq elzar'
# ------------------------------------------------------------
# Clave: 'cngjx' (intento #1,875,283)
# Palabras válidas largas: eluir
# Todas las palabras válidas: cz, jq, eluir
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cz ygqopdfldcñh jq eluir'
# ------------------------------------------------------------
# Clave: 'cngrb' (intento #1,875,503)
# Palabras válidas largas: elmer
# Todas las palabras válidas: cz, fq, elmer
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cz yxnopdwhdcñy fq elmer'
# ------------------------------------------------------------
# Clave: 'cngxf' (intento #1,875,669)
# Palabras válidas largas: elgar
# Todas las palabras válidas: cz, bq, elgar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cz yrjopdqddcñs bq elgar'
# ------------------------------------------------------------
# Clave: 'cnjab' (intento #1,877,204)
# Palabras válidas largas: eider
# Todas las palabras válidas: cz, fq, eider
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cz vonopañhdclp fq eider'
# ------------------------------------------------------------
# Clave: 'cnjxb' (intento #1,877,852)
# Palabras válidas largas: eiger
# Todas las palabras válidas: cz, fq, eiger
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cz vrnopaqhdcls fq eiger'
# ------------------------------------------------------------
# Clave: 'cnljf' (intento #1,878,909)
# Palabras válidas largas: eguar
# Todas las palabras válidas: cz, bq, eguar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cz tgjopyfddcjh bq eguar'
# ------------------------------------------------------------
# Clave: 'cnñmf' (intento #1,881,177)
# Palabras válidas largas: edrar
# Todas las palabras válidas: cz, bq, edrar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cz qdjopvcddcge bq edrar'
# ------------------------------------------------------------
# Clave: 'cnñxf' (intento #1,881,501)
# Palabras válidas largas: edgar
# Todas las palabras válidas: cz, bq, edgar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cz qrjopvqddcgs bq edgar'
# ------------------------------------------------------------
# Clave: 'cnowf' (intento #1,882,203)
# Palabras válidas largas: echar
# Todas las palabras válidas: cz, bq, echar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cz psjopurddcft bq echar'
# ------------------------------------------------------------
# Clave: 'cnqaq' (intento #1,883,052)
# Palabras válidas largas: eador
# Todas las palabras válidas: cz, pq, eador
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cz ñoxopsñrdcdp pq eador'
# ------------------------------------------------------------
# Clave: 'cnqxb' (intento #1,883,684)
# Palabras válidas largas: eager
# Todas las palabras válidas: cz, fq, eager
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cz ñrnopsqhdcds fq eager'
# ------------------------------------------------------------
# Clave: 'cnwsb' (intento #1,887,923)
# Palabras válidas largas: euler
# Todas las palabras válidas: cz, fq, euler
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cz iwnopnvhdcxx fq euler'
# ------------------------------------------------------------
# Clave: 'cnxwb' (intento #1,888,760)
# Palabras válidas largas: ether
# Todas las palabras válidas: cz, fq, ether
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cz hsnopmrhdcwt fq ether'
# ------------------------------------------------------------
# Clave: 'cnxzf' (intento #1,888,845)
# Palabras válidas largas: etear
# Todas las palabras válidas: cz, bq, etear
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cz hpjopmoddcwq bq etear'
# ------------------------------------------------------------
# Clave: 'cnykb' (intento #1,889,138)
# Palabras válidas largas: ester
# Todas las palabras válidas: cz, fq, ester
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cz gfnoplehdcvg fq ester'
# ------------------------------------------------------------
# Clave: 'cnykf' (intento #1,889,142)
# Palabras válidas largas: estar
# Todas las palabras válidas: cz, bq, estar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cz gfjopleddcvg bq estar'
# ------------------------------------------------------------
# Clave: 'cnykq' (intento #1,889,154)
# Palabras válidas largas: estor
# Todas las palabras válidas: cz, pq, estor
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cz gfxoplerdcvg pq estor'
# ------------------------------------------------------------
# Clave: 'cnymf' (intento #1,889,196)
# Palabras válidas largas: esrar
# Todas las palabras válidas: cz, bq, esrar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cz gdjoplcddcve bq esrar'
# ------------------------------------------------------------
# Clave: 'cnzbb' (intento #1,889,624)
# Palabras válidas largas: ercer
# Todas las palabras válidas: cz, fq, ercer
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cz fñnopknhdcuo fq ercer'
# ------------------------------------------------------------
# Clave: 'cnzmf' (intento #1,889,925)
# Palabras válidas largas: errar
# Todas las palabras válidas: cz, bq, errar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cz fdjopkcddcue bq errar'
# ------------------------------------------------------------
# Clave: 'cnzmq' (intento #1,889,937)
# Palabras válidas largas: error
# Todas las palabras válidas: cz, pq, error
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cz fdxopkcrdcue pq error'
# ------------------------------------------------------------
# Clave: 'cnzrf' (intento #1,890,087)
# Palabras válidas largas: ermar
# Todas las palabras válidas: cz, bq, ermar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cz fxjopkwddcuy bq ermar'
# ------------------------------------------------------------
# Clave: 'cñceb' (intento #1,891,892)
# Palabras válidas largas: dozer
# Todas las palabras válidas: cy, fq, dozer
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy clnoohkhdbrm fq dozer'
# ------------------------------------------------------------
# Clave: 'cñceq' (intento #1,891,908)
# Palabras válidas largas: dozor
# Todas las palabras válidas: cy, pq, dozor
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy clxoohkrdbrm pq dozor'
# ------------------------------------------------------------
# Clave: 'cñcib' (intento #1,892,000)
# Palabras válidas largas: dover
# Todas las palabras válidas: cy, fq, dover
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy chnoohghdbri fq dover'
# ------------------------------------------------------------
# Clave: 'cñckf' (intento #1,892,058)
# Palabras válidas largas: dotar
# Todas las palabras válidas: cy, bq, dotar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy cfjooheddbrg bq dotar'
# ------------------------------------------------------------
# Clave: 'cñckq' (intento #1,892,070)
# Palabras válidas largas: dotor
# Todas las palabras válidas: cy, pq, dotor
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy cfxooherdbrg pq dotor'
# ------------------------------------------------------------
# Clave: 'cñcmf' (intento #1,892,112)
# Palabras válidas largas: dorar
# Todas las palabras válidas: cy, bq, dorar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy cdjoohcddbre bq dorar'
# ------------------------------------------------------------
# Clave: 'cñcñf' (intento #1,892,166)
# Palabras válidas largas: dopar
# Todas las palabras válidas: cy, bq, dopar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy cbjoohaddbrc bq dopar'
# ------------------------------------------------------------
# Clave: 'cñcqf' (intento #1,892,247)
# Palabras válidas largas: donar
# Todas las palabras válidas: cy, bq, donar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy cyjoohxddbrz bq donar'
# ------------------------------------------------------------
# Clave: 'cñcqq' (intento #1,892,259)
# Palabras válidas largas: donor
# Todas las palabras válidas: cy, pq, donor
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy cyxoohxrdbrz pq donor'
# ------------------------------------------------------------
# Clave: 'cñcrf' (intento #1,892,274)
# Palabras válidas largas: domar
# Todas las palabras válidas: cy, bq, domar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy cxjoohwddbry bq domar'
# ------------------------------------------------------------
# Clave: 'cñcsb' (intento #1,892,297)
# Palabras válidas largas: doler
# Todas las palabras válidas: cy, fq, doler
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy cwnoohvhdbrx fq doler'
# ------------------------------------------------------------
# Clave: 'cñcsf' (intento #1,892,301)
# Palabras válidas largas: dolar
# Todas las palabras válidas: cy, bq, dolar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy cwjoohvddbrx bq dolar'
# ------------------------------------------------------------
# Clave: 'cñcsq' (intento #1,892,313)
# Palabras válidas largas: dolor
# Todas las palabras válidas: cy, pq, dolor
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy cwxoohvrdbrx pq dolor'
# ------------------------------------------------------------
# Clave: 'cñczf' (intento #1,892,490)
# Palabras válidas largas: doear
# Todas las palabras válidas: cy, bq, doear
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy cpjoohoddbrq bq doear'
# ------------------------------------------------------------
# Clave: 'cñezp' (intento #1,893,959)
# Palabras válidas largas: dnepr
# Todas las palabras válidas: cy, qq, dnepr
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy apyoofosdbpq qq dnepr'
# ------------------------------------------------------------
# Clave: 'cñjib' (intento #1,897,103)
# Palabras válidas largas: diver
# Todas las palabras válidas: cy, fq, diver
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy vhnooaghdbli fq diver'
# ------------------------------------------------------------
# Clave: 'cñjpf' (intento #1,897,323)
# Palabras válidas largas: diñar
# Todas las palabras válidas: cy, bq, diñar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy vzjooayddbla bq diñar'
# ------------------------------------------------------------
# Clave: 'cñjqf' (intento #1,897,350)
# Palabras válidas largas: dinar
# Todas las palabras válidas: cy, bq, dinar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy vyjooaxddblz bq dinar'
# ------------------------------------------------------------
# Clave: 'cñjrx' (intento #1,897,396)
# Palabras válidas largas: dimir
# Todas las palabras válidas: cy, jq, dimir
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy vxqooawldbly jq dimir'
# ------------------------------------------------------------
# Clave: 'cñjsb' (intento #1,897,400)
# Palabras válidas largas: diler
# Todas las palabras válidas: cy, fq, diler
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy vwnooavhdblx fq diler'
# ------------------------------------------------------------
# Clave: 'cñnbq' (intento #1,899,846)
# Palabras válidas largas: decor
# Todas las palabras válidas: cy, pq, decor
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy rñxoownrdbho pq decor'
# ------------------------------------------------------------
# Clave: 'cñnbx' (intento #1,899,853)
# Palabras válidas largas: decir
# Todas las palabras válidas: cy, jq, decir
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy rñqoownldbho jq decir'
# ------------------------------------------------------------
# Clave: 'cñncb' (intento #1,899,857)
# Palabras válidas largas: deber
# Todas las palabras válidas: cy, fq, deber
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy rnnoowmhdbhñ fq deber'
# ------------------------------------------------------------
# Clave: 'cñnpf' (intento #1,900,239)
# Palabras válidas largas: deñar
# Todas las palabras válidas: cy, bq, deñar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy rzjoowyddbha bq deñar'
# ------------------------------------------------------------
# Clave: 'cñnuf' (intento #1,900,374)
# Palabras válidas largas: dejar
# Todas las palabras válidas: cy, bq, dejar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy rujoowtddbhv bq dejar'
# ------------------------------------------------------------
# Clave: 'cñqaq' (intento #1,902,735)
# Palabras válidas largas: dador
# Todas las palabras válidas: cy, pq, dador
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy ñoxoosñrdbdp pq dador'
# ------------------------------------------------------------
# Clave: 'cñqkf' (intento #1,902,993)
# Palabras válidas largas: datar
# Todas las palabras válidas: cy, bq, datar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy ñfjooseddbdg bq datar'
# ------------------------------------------------------------
# Clave: 'cñqmb' (intento #1,903,043)
# Palabras válidas largas: darer
# Todas las palabras válidas: cy, fq, darer
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy ñdnooschdbde fq darer'
# ------------------------------------------------------------
# Clave: 'cñqpf' (intento #1,903,155)
# Palabras válidas largas: dañar
# Todas las palabras válidas: cy, bq, dañar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy ñzjoosyddbda bq dañar'
# ------------------------------------------------------------
# Clave: 'cñqtf' (intento #1,903,263)
# Palabras válidas largas: dakar
# Todas las palabras válidas: cy, bq, dakar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy ñvjoosuddbdw bq dakar'
# ------------------------------------------------------------
# Clave: 'cñqwx' (intento #1,903,363)
# Palabras válidas largas: dahir
# Todas las palabras válidas: cy, jq, dahir
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy ñsqoosrldbdt jq dahir'
# ------------------------------------------------------------
# Clave: 'cñwaf' (intento #1,907,097)
# Palabras válidas largas: dudar
# Todas las palabras válidas: cy, bq, dudar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy iojoonñddbxp bq dudar'
# ------------------------------------------------------------
# Clave: 'cñwmf' (intento #1,907,421)
# Palabras válidas largas: durar
# Todas las palabras válidas: cy, bq, durar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy idjooncddbxe bq durar'
# ------------------------------------------------------------
# Clave: 'cñwsf' (intento #1,907,610)
# Palabras válidas largas: dular
# Todas las palabras válidas: cy, bq, dular
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy iwjoonvddbxx bq dular'
# ------------------------------------------------------------
# Clave: 'cñxrt' (intento #1,908,327)
# Palabras válidas largas: dtmmr
# Todas las palabras válidas: cy, nq, dtmmr
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy hxuoomwodbwy nq dtmmr'
# ------------------------------------------------------------
# Clave: 'cñykf' (intento #1,908,825)
# Palabras válidas largas: dstar
# Todas las palabras válidas: cy, bq, dstar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cy gfjooleddbvg bq dstar'
# ------------------------------------------------------------
# Clave: 'cocab' (intento #1,911,467)
# Palabras válidas largas: coder
# Todas las palabras válidas: cx, fq, coder
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx conoñhñhdarp fq coder'
# ------------------------------------------------------------
# Clave: 'cocbb' (intento #1,911,494)
# Palabras válidas largas: cocer
# Todas las palabras válidas: cx, fq, cocer
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx cñnoñhnhdaro fq cocer'
# ------------------------------------------------------------
# Clave: 'cocbf' (intento #1,911,498)
# Palabras válidas largas: cocar
# Todas las palabras válidas: cx, bq, cocar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx cñjoñhnddaro bq cocar'
# ------------------------------------------------------------
# Clave: 'cocib' (intento #1,911,683)
# Palabras válidas largas: cover
# Todas las palabras válidas: cx, fq, cover
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx chnoñhghdari fq cover'
# ------------------------------------------------------------
# Clave: 'cockf' (intento #1,911,741)
# Palabras válidas largas: cotar
# Todas las palabras válidas: cx, bq, cotar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx cfjoñheddarg bq cotar'
# ------------------------------------------------------------
# Clave: 'coclb' (intento #1,911,764)
# Palabras válidas largas: coser
# Todas las palabras válidas: cx, fq, coser
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx cenoñhdhdarf fq coser'
# ------------------------------------------------------------
# Clave: 'cocmf' (intento #1,911,795)
# Palabras válidas largas: corar
# Todas las palabras válidas: cx, bq, corar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx cdjoñhcddare bq corar'
# ------------------------------------------------------------
# Clave: 'cocñf' (intento #1,911,849)
# Palabras válidas largas: copar
# Todas las palabras válidas: cx, bq, copar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx cbjoñhaddarc bq copar'
# ------------------------------------------------------------
# Clave: 'cocrb' (intento #1,911,953)
# Palabras válidas largas: comer
# Todas las palabras válidas: cx, fq, comer
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx cxnoñhwhdary fq comer'
# ------------------------------------------------------------
# Clave: 'cocsf' (intento #1,911,984)
# Palabras válidas largas: colar
# Todas las palabras válidas: cx, bq, colar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx cwjoñhvddarx bq colar'
# ------------------------------------------------------------
# Clave: 'cocsq' (intento #1,911,996)
# Palabras válidas largas: color
# Todas las palabras válidas: cx, pq, color
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx cwxoñhvrdarx pq color'
# ------------------------------------------------------------
# Clave: 'cocxb' (intento #1,912,115)
# Palabras válidas largas: coger
# Todas las palabras válidas: cx, fq, coger
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx crnoñhqhdars fq coger'
# ------------------------------------------------------------
# Clave: 'cogzf' (intento #1,915,089)
# Palabras válidas largas: clear
# Todas las palabras válidas: cx, bq, clear
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx ypjoñdoddañq bq clear'
# ------------------------------------------------------------
# Clave: 'cojab' (intento #1,916,570)
# Palabras válidas largas: cider
# Todas las palabras válidas: cx, fq, cider
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx vonoñañhdalp fq cider'
# ------------------------------------------------------------
# Clave: 'cojkf' (intento #1,916,844)
# Palabras válidas largas: citar
# Todas las palabras válidas: cx, bq, citar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx vfjoñaeddalg bq citar'
# ------------------------------------------------------------
# Clave: 'cojrf' (intento #1,917,060)
# Palabras válidas largas: cimar
# Todas las palabras válidas: cx, bq, cimar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx vxjoñawddaly bq cimar'
# ------------------------------------------------------------
# Clave: 'cojxf' (intento #1,917,222)
# Palabras válidas largas: cigar
# Todas las palabras válidas: cx, bq, cigar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx vrjoñaqddals bq cigar'
# ------------------------------------------------------------
# Clave: 'cokdf' (intento #1,917,384)
# Palabras válidas largas: chaar
# Todas las palabras válidas: cx, bq, chaar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx umjoñzlddakn bq chaar'
# ------------------------------------------------------------
# Clave: 'cokdx' (intento #1,917,403)
# Palabras válidas largas: chair
# Todas las palabras válidas: cx, jq, chair
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx umqoñzlldakn jq chair'
# ------------------------------------------------------------
# Clave: 'cokox' (intento #1,917,727)
# Palabras válidas largas: choir
# Todas las palabras válidas: cx, jq, choir
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx uaqoñzzldakb jq choir'
# ------------------------------------------------------------
# Clave: 'cokvf' (intento #1,917,897)
# Palabras válidas largas: chiar
# Todas las palabras válidas: cx, bq, chiar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx utjoñzsddaku bq chiar'
# ------------------------------------------------------------
# Clave: 'cokzb' (intento #1,918,001)
# Palabras válidas largas: cheer
# Todas las palabras válidas: cx, fq, cheer
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx upnoñzohdakq fq cheer'
# ------------------------------------------------------------
# Clave: 'conab' (intento #1,919,486)
# Palabras válidas largas: ceder
# Todas las palabras válidas: cx, fq, ceder
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx ronoñwñhdahp fq ceder'
# ------------------------------------------------------------
# Clave: 'conaf' (intento #1,919,490)
# Palabras válidas largas: cedar
# Todas las palabras válidas: cx, bq, cedar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx rojoñwñddahp bq cedar'
# ------------------------------------------------------------
# Clave: 'concf' (intento #1,919,544)
# Palabras válidas largas: cebar
# Todas las palabras válidas: cx, bq, cebar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx rnjoñwmddahñ bq cebar'
# ------------------------------------------------------------
# Clave: 'conlf' (intento #1,919,787)
# Palabras válidas largas: cesar
# Todas las palabras válidas: cx, bq, cesar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx rejoñwdddahf bq cesar'
# ------------------------------------------------------------
# Clave: 'conpf' (intento #1,919,922)
# Palabras válidas largas: ceñar
# Todas las palabras válidas: cx, bq, ceñar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx rzjoñwyddaha bq ceñar'
# ------------------------------------------------------------
# Clave: 'conpx' (intento #1,919,941)
# Palabras válidas largas: ceñir
# Todas las palabras válidas: cx, jq, ceñir
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx rzqoñwyldaha jq ceñir'
# ------------------------------------------------------------
# Clave: 'conqf' (intento #1,919,949)
# Palabras válidas largas: cenar
# Todas las palabras válidas: cx, bq, cenar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx ryjoñwxddahz bq cenar'
# ------------------------------------------------------------
# Clave: 'consf' (intento #1,920,003)
# Palabras válidas largas: celar
# Todas las palabras válidas: cx, bq, celar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx rwjoñwvddahx bq celar'
# ------------------------------------------------------------
# Clave: 'conuf' (intento #1,920,057)
# Palabras válidas largas: cejar
# Todas las palabras válidas: cx, bq, cejar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx rujoñwtddahv bq cejar'
# ------------------------------------------------------------
# Clave: 'conxf' (intento #1,920,138)
# Palabras válidas largas: cegar
# Todas las palabras válidas: cx, bq, cegar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx rrjoñwqddahs bq cegar'
# ------------------------------------------------------------
# Clave: 'coqab' (intento #1,922,402)
# Palabras válidas largas: cader
# Todas las palabras válidas: cx, fq, cader
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx ñonoñsñhdadp fq cader'
# ------------------------------------------------------------
# Clave: 'coqcb' (intento #1,922,456)
# Palabras válidas largas: caber
# Todas las palabras válidas: cx, fq, caber
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx ñnnoñsmhdadñ fq caber'
# ------------------------------------------------------------
# Clave: 'coqef' (intento #1,922,514)
# Palabras válidas largas: cazar
# Todas las palabras válidas: cx, bq, cazar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx ñljoñskddadm bq cazar'
# ------------------------------------------------------------
# Clave: 'coqif' (intento #1,922,622)
# Palabras válidas largas: cavar
# Todas las palabras válidas: cx, bq, cavar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx ñhjoñsgddadi bq cavar'
# ------------------------------------------------------------
# Clave: 'coqkf' (intento #1,922,676)
# Palabras válidas largas: catar
# Todas las palabras válidas: cx, bq, catar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx ñfjoñseddadg bq catar'
# ------------------------------------------------------------
# Clave: 'coqlf' (intento #1,922,703)
# Palabras válidas largas: casar
# Todas las palabras válidas: cx, bq, casar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx ñejoñsdddadf bq casar'
# ------------------------------------------------------------
# Clave: 'coqñf' (intento #1,922,784)
# Palabras válidas largas: capar
# Todas las palabras válidas: cx, bq, capar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx ñbjoñsaddadc bq capar'
# ------------------------------------------------------------
# Clave: 'coqpf' (intento #1,922,838)
# Palabras válidas largas: cañar
# Todas las palabras válidas: cx, bq, cañar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx ñzjoñsyddada bq cañar'
# ------------------------------------------------------------
# Clave: 'coqsb' (intento #1,922,915)
# Palabras válidas largas: caler
# Todas las palabras válidas: cx, fq, caler
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'cx ñwnoñsvhdadx fq caler'
# ------------------------------------------------------------
# Clave: 'coqsf' (intento #1,922,919)
# Palabras válidas largas: calar
# Todas las palabras válidas: cx, bq, calar
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# ...
# ------------------------------------------------------------
# Clave: 'efsdp' (intento #2,790,008)
# Palabras válidas largas: myapp
# Todas las palabras válidas: ah, qo, myapp
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ah mmynxqlsbkbn qo myapp'
# ------------------------------------------------------------
# Clave: 'efsym' (intento #2,790,598)
# Palabras válidas largas: myftp
# Todas las palabras válidas: ah, uo, myftp
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ah mqcnxqpwbkbr uo myftp'
# ------------------------------------------------------------
# Clave: 'efywq' (intento #2,794,923)
# Palabras válidas largas: mshop
# Todas las palabras válidas: ah, po, mshop
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ah gsxnxlrrbkvt po mshop'
# ------------------------------------------------------------
# Clave: 'egcoq' (intento #2,797,623)
# Palabras válidas largas: looop
# Todas las palabras válidas: ag, po, looop
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ag caxnwhzrbjrb po looop'
# ------------------------------------------------------------
# Clave: 'ehxhq' (intento #2,833,128)
# Palabras válidas largas: ktwop
# Todas las palabras válidas: af, po, ktwop
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'af hixnvmhrbiwj po ktwop'
# ------------------------------------------------------------
# Clave: 'ejbbq' (intento #2,855,565)
# Palabras válidas largas: ipcop
# Todas las palabras válidas: ad, po, ipcop
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ad dñxntinrbgso po ipcop'
# ------------------------------------------------------------
# Clave: 'ejfld' (intento #2,858,737)
# Palabras válidas largas: imscp
# Todas las palabras válidas: ad, do, imscp
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ad zelntedfbgof do imscp'
# ------------------------------------------------------------
# Clave: 'ejyñd' (intento #2,873,398)
# Palabras válidas largas: ispcp
# Todas las palabras válidas: ad, do, ispcp
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ad gblntlafbgvc do ispcp'
# ------------------------------------------------------------
# Clave: 'ejyrm' (intento #2,873,515)
# Palabras válidas largas: ismtp
# Todas las palabras válidas: ad, uo, ismtp
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ad gxcntlwwbgvy uo ismtp'
# ------------------------------------------------------------
# Clave: 'ejywq' (intento #2,873,655)
# Palabras válidas largas: ishop
# Todas las palabras válidas: ad, po, ishop
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ad gsxntlrrbgvt po ishop'
# ------------------------------------------------------------
# Clave: 'eksam' (intento #2,888,338)
# Palabras válidas largas: hydtp
# Todas las palabras válidas: ac, uo, hydtp
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ac mocnsqñwbfbp uo hydtp'
# ------------------------------------------------------------
# Clave: 'elmsq' (intento #2,903,436)
# Palabras válidas largas: gflop
# Todas las palabras válidas: ab, po, gflop
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ab swxnrxvrbeix po gflop'
# ------------------------------------------------------------
# Clave: 'elnox' (intento #2,904,064)
# Palabras válidas largas: geoip
# Todas las palabras válidas: ab, jo, geoip
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ab raqnrwzlbehb jo geoip'
# ------------------------------------------------------------
# Clave: 'elqsq' (intento #2,907,081)
# Palabras válidas largas: galop
# Todas las palabras válidas: ab, po, galop
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ab ñwxnrsvrbedx po galop'
# ------------------------------------------------------------
# Clave: 'elzdn' (intento #2,913,206)
# Palabras válidas largas: grasp
# Todas las palabras válidas: ab, to, grasp
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ab fmbnrklvbeun to grasp'
# ------------------------------------------------------------
# Clave: 'elzol' (intento #2,913,528)
# Palabras válidas largas: group
# Todas las palabras válidas: ab, vo, group
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ab fadnrkzxbeub vo group'
# ------------------------------------------------------------
# Clave: 'emejt' (intento #2,917,020)
# Palabras válidas largas: fnump
# Todas las palabras válidas: aa, no, fnump
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'aa agunqffobdph no fnump'
# ------------------------------------------------------------
# Clave: 'emjsx' (intento #2,920,939)
# Palabras válidas largas: filip
# Todas las palabras válidas: aa, jo, filip
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'aa vwqnqavlbdlx jo filip'
# ------------------------------------------------------------
# Clave: 'empdp' (intento #2,925,602)
# Palabras válidas largas: fbapp
# Todas las palabras válidas: aa, qo, fbapp
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'aa omynqtlsbden qo fbapp'
# ------------------------------------------------------------
# Clave: 'enajx' (intento #2,933,791)
# Palabras válidas largas: equip
# Todas las palabras válidas: az, jo, equip
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'az egqnpjflbcth jo equip'
# ------------------------------------------------------------
# Clave: 'enooñ' (intento #2,944,878)
# Palabras válidas largas: ecorp
# Todas las palabras válidas: az, so, ecorp
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'az paanpuzubcfb so ecorp'
# ------------------------------------------------------------
# Clave: 'enyrm' (intento #2,952,247)
# Palabras válidas largas: esmtp
# Todas las palabras válidas: az, uo, esmtp
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'az gxcnplwwbcvy uo esmtp'
# ------------------------------------------------------------
# Clave: 'enywq' (intento #2,952,387)
# Palabras válidas largas: eshop
# Todas las palabras válidas: az, po, eshop
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'az gsxnplrrbcvt po eshop'
# ------------------------------------------------------------
# Clave: 'eñsqx' (intento #2,967,541)
# Palabras válidas largas: dynip
# Todas las palabras válidas: ay, jo, dynip
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ay myqnoqxlbbbz jo dynip'
# ------------------------------------------------------------
# Clave: 'eofdp' (intento #2,976,632)
# Palabras válidas largas: cmapp
# Todas las palabras válidas: ax, qo, cmapp
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ax zmynñelsbaon qo cmapp'
# ------------------------------------------------------------
# Clave: 'eogdt' (intento #2,977,365)
# Palabras válidas largas: clamp
# Todas las palabras válidas: ax, no, clamp
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ax ymunñdlobañn no clamp'
# ------------------------------------------------------------
# Clave: 'eokdt' (intento #2,980,281)
# Palabras válidas largas: champ
# Todas las palabras válidas: ax, no, champ
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ax umunñzlobakn no champ'
# ------------------------------------------------------------
# Clave: 'eokvñ' (intento #2,980,788)
# Palabras válidas largas: chirp
# Todas las palabras válidas: ax, so, chirp
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ax utanñzsubaku so chirp'
# ------------------------------------------------------------
# Clave: 'eokvt' (intento #2,980,794)
# Palabras válidas largas: chimp
# Todas las palabras válidas: ax, no, chimp
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ax utunñzsobaku no chimp'
# ------------------------------------------------------------
# Clave: 'eokzf' (intento #2,980,887)
# Palabras válidas largas: cheap
# Todas las palabras válidas: ax, bo, cheap
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ax upjnñzodbakq bo cheap'
# ------------------------------------------------------------
# Clave: 'eozvn' (intento #2,992,451)
# Palabras válidas largas: crisp
# Todas las palabras válidas: ax, to, crisp
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ax ftbnñksvbauu to crisp'
# ------------------------------------------------------------
# Clave: 'epjxx' (intento #2,999,806)
# Palabras válidas largas: bigip
# Todas las palabras válidas: aw, jo, bigip
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'aw vrqnnaqlbzls jo bigip'
# ------------------------------------------------------------
# Clave: 'epncq' (intento #3,002,121)
# Palabras válidas largas: bebop
# Todas las palabras válidas: aw, po, bebop
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'aw rnxnnwmrbzhñ po bebop'
# ------------------------------------------------------------
# Clave: 'epyrm' (intento #3,011,296)
# Palabras válidas largas: bsmtp
# Todas las palabras válidas: aw, uo, bsmtp
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'aw gxcnnlwwbzvy uo bsmtp'
# ------------------------------------------------------------
# Clave: 'eqnlq' (intento #3,022,047)
# Palabras válidas largas: aesop
# Todas las palabras válidas: av, po, aesop
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'av rexnmwdrbyhf po aesop'
# ------------------------------------------------------------
# Clave: 'eqyrm' (intento #3,030,979)
# Palabras válidas largas: asmtp
# Todas las palabras válidas: av, uo, asmtp
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'av gxcnmlwwbyvy uo asmtp'
# ------------------------------------------------------------
# Clave: 'eqzlx' (intento #3,031,531)
# Palabras válidas largas: arsip
# Todas las palabras válidas: av, jo, arsip
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'av feqnmkdlbyuf jo arsip'
# ------------------------------------------------------------
# Clave: 'erwsx' (intento #3,049,243)
# Palabras válidas largas: zulip
# Todas las palabras válidas: au, jo, zulip
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'au iwqnlnvlbxxx jo zulip'
# ------------------------------------------------------------
# Clave: 'etñrd' (intento #3,082,000)
# Palabras válidas largas: xdmcp
# Todas las palabras válidas: as, do, xdmcp
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'as qxlnjvwfbvgy do xdmcp'
# ------------------------------------------------------------
# Clave: 'eucax' (intento #3,092,470)
# Palabras válidas largas: wodip
# Todas las palabras válidas: ar, jo, wodip
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ar coqnihñlburp jo wodip'
# ------------------------------------------------------------
# Clave: 'eujqi' (intento #3,098,016)
# Palabras válidas largas: winxp
# Todas las palabras válidas: ar, yo, winxp
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'ar vygniaxabulz yo winxp'
# ------------------------------------------------------------
# Clave: 'evbld' (intento #3,111,700)
# Palabras válidas largas: vpscp
# Todas las palabras válidas: aq, do, vpscp
# Estadísticas detalladas:
#    - Total palabras: 4
#    - Palabras válidas (todas): 3 (75.0%)
#    - Palabras válidas largas: 1 (50.0%)
# Texto descifrado: 'aq delnhidfbtsf do vpscp'
# ------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-fa11d93539fd> in <cell line: 0>()
#     191
#     192     # Ejecutar ataque de fuerza bruta
# --> 193     clave_encontrada, texto_descifrado = ataque_fuerza_bruta_completa(
#     194         texto_cifrado,
#     195         diccionario,
#
# <ipython-input-4-fa11d93539fd> in ataque_fuerza_bruta_completa(texto_cifrado, diccionario, longitud_maxima_clave, mostrar_progreso, limite_candidatos)
#     132
#     133         # Validar el resultado
# --> 134         es_muy_probable, detalles = validar_texto_completo(texto_descifrado, diccionario)
#     135
#     136         # Si encontramos un candidato muy probable, lo guardamos
#
# <ipython-input-4-fa11d93539fd> in validar_texto_completo(texto_descifrado, diccionario, longitud_minima, porcentaje_minimo)
#      63
#      64     palabras_largas = [p for p in palabras if len(p) >= longitud_minima]
# ---> 65     palabras_validas = [p for p in palabras_largas if p in diccionario]
#      66
#      67     todas_palabras_validas = [p for p in palabras if p in diccionario]
#
# <ipython-input-4-fa11d93539fd> in <listcomp>(.0)
#      63
#      64     palabras_largas = [p for p in palabras if len(p) >= longitud_minima]
# ---> 65     palabras_validas = [p for p in palabras_largas if p in diccionario]
#      66
#      67     todas_palabras_validas = [p for p in palabras if p in diccionario]
#
# KeyboardInterrupt:
